# %%
import numpy as np
import pandas as pd
import os
import ffmpeg
from IPython.display import Audio

# %%
cv_dir = "/scratch/ci411/spokenweb/commonvoice/"
cvout_dir = "/scratch/ci411/spokenweb/commonvoice_reshaped/"

# %%
train_df = pd.read_csv(cv_dir + 'train.tsv', sep='\t')

# %%
train_df.columns
# Out:
# Index(['client_id', 'path', 'sentence', 'up_votes', 'down_votes', 'age',
#        'gender', 'accent'],
#       dtype='object')

# %%
min_utter = 10
train_grouped = train_df.groupby('client_id', sort=False)
train_grouped_df = train_grouped.count().reset_index()
train_sorted = train_grouped_df.sort_values('path', ascending=False).reset_index()
train_sorted_fil = train_sorted[train_grouped_df['path']>min_utter]
print('All samples:{}'.format(train_sorted.shape[0]))
print('Filtered Samples with at least {} utterances: {}'.format(min_utter, train_sorted_fil.shape[0]))
# Out:
# All samples:1057
# Filtered Samples with at least 10 utterances: 206

# %%
for speaker in train_sorted_fil['client_id']:
    speaker_dir = os.path.join(cvout_dir, speaker)
    audio_dir = os.path.join(speaker_dir,'audio')
    print(speaker_dir)
    print()
    print(audio_dir)
    print()
    for path in train_grouped.get_group(speaker)['path']:
        utt_in = os.path.join(cv_dir,'clips',path+'.mp3')
        utt_out = os.path.join(audio_dir, path+'.wav')
        print(utt_in)
        print()
        print(utt_out)
        print()
        break
    break
# Out:
# /scratch/ci411/spokenweb/commonvoice_reshaped/9074c639bd7acb5a69e2eadf20838072bb89053cd0f523ee44fe3f3961fb04efc74644cc41b36357c2a0cfad69776215734b370b8e1d9a2cba3c0ad9f00a2987
#
# /scratch/ci411/spokenweb/commonvoice_reshaped/9074c639bd7acb5a69e2eadf20838072bb89053cd0f523ee44fe3f3961fb04efc74644cc41b36357c2a0cfad69776215734b370b8e1d9a2cba3c0ad9f00a2987/audio
#
# /scratch/ci411/spokenweb/commonvoice/clips/e39db314d7aa8d29c4a8e7058adc89c8816a671a21ce4adc654594508293f3e09689b8a285320e23a27ceaec8c2f7edc60cb9be3fec570d42bf6bff236f56d6a.mp3
#
# /scratch/ci411/spokenweb/commonvoice_.wav

# %%
#os.mkdir(speaker_dir)
#os.mkdir(audio_dir)

ffmpeg.input(utt_in).output(utt_out).run()
# Out:
# (None, None)

# %%
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
